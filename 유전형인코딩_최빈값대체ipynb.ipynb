# %% [markdown]
# <a href="https://colab.research.google.com/github/shwoa/Capstone/blob/main/%EC%9C%A0%EC%A0%84%ED%98%95%EC%9D%B8%EC%BD%94%EB%94%A9_%EC%B5%9C%EB%B9%88%EA%B0%92%EB%8C%80%EC%B2%B4ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📌 1. Colab에서 파일 업로드
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-63f6a830-553b-4abd-9572-0c00887001ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63f6a830-553b-4abd-9572-0c00887001ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 📌 2. 데이터 로딩
import pandas as pd
import numpy as np

file_name = "토마토_유전형.CSV"  # 업로드한 파일명에 맞게 수정
geno_raw = pd.read_csv(file_name, index_col=0)

# 📌 3. 전치 및 'Chr', 'Position (bp)' 제거
geno_T = geno_raw.drop(columns=["Chr", "Position (bp)"]).T.replace("NN", np.nan)

# 📌 4. 염기 인코딩 규칙 (AC/CA → 12 형태)
base_encoding = {'A': '1', 'C': '2', 'G': '3', 'T': '4'}
def encode_snp_sorted(snp):
    if pd.isna(snp):
        return np.nan
    sorted_snp = ''.join(sorted(snp))
    return int(''.join([base_encoding.get(base, '0') for base in sorted_snp]))

# 📌 5. 문자 SNP → 숫자 인코딩
geno_encoded = geno_T.applymap(encode_snp_sorted)

# 📌 6. 결측치 → 최빈값으로 대체 + 정수형 변환
geno_filled = geno_encoded.apply(
    lambda col: col.fillna(col.mode().iloc[0]).astype(int), axis=0
)

# 📌 7. 전치 (샘플을 행, SNP를 열로 보기 좋게)
geno_final = geno_filled.T

# 📌 8. CSV로 저장
output_filename = "전처리된_유전형_최빈값_전치.csv"
geno_final.to_csv(output_filename, encoding='utf-8-sig', index=True)

# 📌 9. 다운로드
files.download(output_filename)
# Out:
# <ipython-input-12-e4adbd6dcba3>:20: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   geno_encoded = geno_T.applymap(encode_snp_sorted)
